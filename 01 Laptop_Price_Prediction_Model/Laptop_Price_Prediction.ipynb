# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../DATA/laptop.csv')

# %%
df
# Out:
#      Company            TypeName  Screen_Size Resolution Touchscreen  IPS  \
# 0      Apple           Ultrabook         13.3  2560x1600          No  Yes
# 1      Apple           Ultrabook         13.3   1440x900          No   No
# 2         HP            Notebook         15.6  1920x1080          No   No
# 3      Apple           Ultrabook         15.4  2880x1800          No  Yes
# 4      Apple           Ultrabook         13.3  2560x1600          No  Yes
# ...      ...                 ...          ...        ...         ...  ...
# 1252  Lenovo  2 in 1 Convertible         14.0  1920x1080         Yes  Yes
# 1253  Lenovo  2 in 1 Convertible         13.3  3200x1800         Yes  Yes
# 1254  Lenovo            Notebook         14.0   1366x768          No   No
# 1255      HP            Notebook         15.6   1366x768          No   No
# 1256    Asus            Notebook         15.6   1366x768          No   No
#
#                           CPU  Clock_Speed  RAM                       GPU  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1257 non-null   object
#  1   TypeName       1257 non-null   object
#  2   Screen_Size    1257 non-null   float64
#  3   Resolution     1257 non-null   object
#  4   Touchscreen    1257 non-null   object
#  5   IPS            1257 non-null   object
#  6   CPU            1257 non-null   object
#  7   Clock_Speed    1257 non-null   float64
#  8   RAM            1257 non-null   int64
#  9   GPU            1257 non-null   object
#  10  HDD            1257 non-null   int64
#  11  SSD            1257 non-null   int64
#  12  Flash_Storage  1257 non-null   int64
#  13  OpSys          1257 non-null   object
#  14  Weight         1257 non-null   float64
#  15  Price          1257 non-null   float64
# dtypes: float64(4), int64(4), object(8)
# memory usage: 157.3+ KB

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)
# Out:
#                Screen_Size  Clock_Speed       RAM       HDD       SSD  \
# Screen_Size       1.000000     0.200538  0.137624  0.013850 -0.088566
# Clock_Speed       0.200538     1.000000  0.336262  0.013848  0.260945
# RAM               0.137624     0.336262  1.000000 -0.021132  0.570342
# HDD               0.013850     0.013848 -0.021132  1.000000 -0.035360
# SSD              -0.088566     0.260945  0.570342 -0.035360  1.000000
# Flash_Storage    -0.172358    -0.222291 -0.055127 -0.006415 -0.148835
# Weight            0.492894     0.274459  0.273218  0.008613 -0.030981
# Price             0.040704     0.432411  0.684193 -0.021990  0.668499
#
#                Flash_Storage    Weight     Price
# Screen_Size        -0.172358  0.492894  0.040704
# Clock_Speed        -0.222291  0.274459  0.432411
# RAM                -0.055127  0.273218  0.684193
# HDD                -0.006415  0.008613 -0.021990
# SSD                -0.148835 -0.030981  0.668499
# ...

# %%
sns.scatterplot(x='Price', y='RAM', data=df)
# Out:
# <Axes: xlabel='Price', ylabel='RAM'>

# %%
df[(df['RAM']>60) & (df['Price']<3000)]
# Out:
#      Company   TypeName  Screen_Size Resolution Touchscreen  IPS  \
# 68      Dell  Ultrabook         13.3  1920x1080          No  Yes
# 699   Lenovo  Ultrabook         14.0  2560x1440          No  Yes
# 1032    Asus     Gaming         17.3  1920x1080          No  Yes
#
#                 CPU  Clock_Speed  RAM                 GPU  HDD   SSD  \
# 68    Intel Core i7          1.8   64         AMD Radeon     0   256
# 699   Intel Core i7          2.5   64   Intel HD Graphics    0   512
# 1032  Intel Core i7          2.7   64  Nvidia GeForce GTX    0  1000
#
#       Flash_Storage    OpSys  Weight    Price
# 68                0  Windows    1.40   641.12
# 699               0  Windows    1.17  1132.29
# 1032              0  Windows    3.58  2668.53

# %%
df = df.drop([68, 699, 1032])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1254 entries, 0 to 1256
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1254 non-null   object
#  1   TypeName       1254 non-null   object
#  2   Screen_Size    1254 non-null   float64
#  3   Resolution     1254 non-null   object
#  4   Touchscreen    1254 non-null   object
#  5   IPS            1254 non-null   object
#  6   CPU            1254 non-null   object
#  7   Clock_Speed    1254 non-null   float64
#  8   RAM            1254 non-null   int64
#  9   GPU            1254 non-null   object
#  10  HDD            1254 non-null   int64
#  11  SSD            1254 non-null   int64
#  12  Flash_Storage  1254 non-null   int64
#  13  OpSys          1254 non-null   object
#  14  Weight         1254 non-null   float64
#  15  Price          1254 non-null   float64
# dtypes: float64(4), int64(4), object(8)
# memory usage: 166.5+ KB

# %%
df[(df['RAM']>=30) & (df['Price']>3000)]
# Out:
#     Company  TypeName  Screen_Size Resolution Touchscreen  IPS            CPU  \
# 188   Razer    Gaming         17.3  3840x2160         Yes   No  Intel Core i7
# 594  Lenovo  Notebook         15.6  3840x2160          No  Yes     Intel Xeon
# 804   Razer    Gaming         17.3  3840x2160         Yes   No  Intel Core i7
#
#      Clock_Speed  RAM                 GPU  HDD   SSD  Flash_Storage    OpSys  \
# 188          2.9   32  Nvidia GeForce GTX    0  1000              0  Windows
# 594          3.1   32       Nvidia Quadro    0  1000              0  Windows
# 804          2.9   32  Nvidia GeForce GTX    0   512              0  Windows
#
#      Weight    Price
# 188    3.49  4094.43
# 594    2.50  3288.84
# 804    3.49  3691.63

# %%
df = df.drop([188, 594, 804])

# %%
sns.scatterplot(x='Price', y='SSD', data=df)
# Out:
# <Axes: xlabel='Price', ylabel='SSD'>

# %%
df[(df['SSD']<=512) & (df['Price']>2500)]
# Out:
#      Company     TypeName  Screen_Size Resolution Touchscreen  IPS  \
# 228     Asus       Gaming         17.3  1920x1080          No   No
# 726       HP  Workstation         17.3  1920x1080          No  Yes
# 1099      HP  Workstation         17.3  1920x1080          No  Yes
#
#                 CPU  Clock_Speed  RAM                 GPU   HDD  SSD  \
# 228   Intel Core i7          2.9   32  Nvidia GeForce GTX  1000  512
# 726      Intel Xeon          2.9   16       Nvidia Quadro     0  256
# 1099  Intel Core i7          2.6    8       Nvidia Quadro     0  256
#
#       Flash_Storage    OpSys  Weight    Price
# 228               0  Windows     4.7  2611.47
# 726               0  Windows     3.0  2946.46
# 1099              0  Windows     3.0  2651.34

# %%
df = df.drop([228, 726, 1099])

# %%
sns.scatterplot(x='Price', y='Clock_Speed', data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Clock_Speed'>

# %%
df[(df['Clock_Speed']<1.5) & (df['Price']>2000)]
# Out:
#     Company   TypeName  Screen_Size Resolution Touchscreen IPS           CPU  \
# 885      HP  Ultrabook         12.5  3840x2160         Yes  No  Intel Core M
#
#      Clock_Speed  RAM                GPU  HDD  SSD  Flash_Storage    OpSys  \
# 885          1.2    8  Intel HD Graphics    0  240              0  Windows
#
#      Weight    Price
# 885    1.09  2081.12

# %%
df = df.drop(885)

# %%
df[(df['Clock_Speed']>3.5) & (df['Price']<1000)]
# Out:
#      Company  TypeName  Screen_Size Resolution Touchscreen IPS  \
# 329   Lenovo  Notebook         15.6  1920x1080          No  No
# 575   Lenovo  Notebook         15.6  1920x1080          No  No
# 681   Lenovo  Notebook         15.6   1366x768          No  No
# 951   Lenovo  Notebook         15.6  1920x1080          No  No
# 1199  Lenovo  Notebook         15.6  1920x1080          No  No
#
#                  CPU  Clock_Speed  RAM            GPU   HDD  SSD  \
# 329   AMD A12-Series          3.6   12    AMD Radeon   2000    0
# 575   AMD A12-Series          3.6   12    AMD Radeon      0  512
# 681   AMD A12-Series          3.6    8  AMD Radeon R7  1000    0
# 951   AMD A12-Series          3.6    6    AMD Radeon      0  256
# 1199  AMD A12-Series          3.6    6    AMD Radeon      0  256
#
#       Flash_Storage    OpSys  Weight   Price
# 329               0  Windows     2.2  603.52
# 575               0  Windows     2.2  637.09
# 681               0  Windows     2.2  288.00
# ...

# %%
df = df.drop([681, 951, 1199, 329, 575])

# %%
sns.scatterplot(x='Price', y='Weight', data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Weight'>

# %%
df[(df['Weight']>4.5) & (df['Price']<1500)]
# Out:
#      Company   TypeName  Screen_Size Resolution Touchscreen  IPS  \
# 128     Acer   Notebook         15.6  1920x1080          No   No
# 166  Toshiba   Notebook         15.6   1366x768          No   No
# 230   Lenovo   Notebook         15.6   1366x768          No   No
# 291   Lenovo   Notebook         17.3   1600x900          No   No
# 315     Acer   Notebook         15.6   1366x768          No   No
# 571   Lenovo  Ultrabook         14.0  1920x1080          No  Yes
# 611     Asus  Ultrabook         14.0  1920x1080          No   No
# 637     Dell   Notebook         15.6  1920x1080          No   No
#
#                CPU  Clock_Speed  RAM                 GPU   HDD  SSD  \
# 128  Intel Core i3          2.7    4      Nvidia GeForce     0  256
# 166  Intel Core i3          2.4    4   Intel HD Graphics   500    0
# 230  Intel Core i3          2.0    8   Intel HD Graphics     0  128
# 291  Intel Core i5          2.5    6  Nvidia GeForce GTX  1000    0
# ...

# %%
df = df.drop([128, 166, 230, 291, 315, 571, 611, 637])

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import ElasticNetCV, LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop('Price', axis=1)

# %%
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=104)

# %%
df.head()
# Out:
#   Company   TypeName  Screen_Size Resolution Touchscreen  IPS            CPU  \
# 0   Apple  Ultrabook         13.3  2560x1600          No  Yes  Intel Core i5
# 1   Apple  Ultrabook         13.3   1440x900          No   No  Intel Core i5
# 2      HP   Notebook         15.6  1920x1080          No   No  Intel Core i5
# 3   Apple  Ultrabook         15.4  2880x1800          No  Yes  Intel Core i7
# 4   Apple  Ultrabook         13.3  2560x1600          No  Yes  Intel Core i5
#
#    Clock_Speed  RAM                       GPU  HDD  SSD  Flash_Storage  OpSys  \
# 0          2.3    8  Intel Iris Plus Graphics    0  128              0  MacOS
# 1          1.8    8         Intel HD Graphics    0    0            128  MacOS
# 2          2.5    8         Intel HD Graphics    0  256              0  No OS
# 3          2.7   16           AMD Radeon Pro     0  512              0  MacOS
# 4          3.1    8  Intel Iris Plus Graphics    0  256              0  MacOS
#
#    Weight    Price
# ...

# %%
cat_features = X_train.select_dtypes(include="object").columns.tolist()

# %%
num_features = X_train.select_dtypes(include=["int64", "float64"]).columns.tolist()

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import RidgeCV

num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('poly', PolynomialFeatures(degree=2, interaction_only=True, include_bias=False))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features),
        ('num', num_transformer, num_features)
    ],
    remainder='passthrough'
)

model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', ElasticNetCV(cv=10, l1_ratio=[.1, .5, .7,.9, .95, .99, 1], max_iter=1_000_000)) 
])

# %%
model_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Company', 'TypeName',
#                                                    'Resolution', 'Touchscreen',
#                                                    'IPS', 'CPU', 'GPU',
#                                                    'OpSys']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures(include_bias=False,
# ...

# %%
best_model = model_pipeline.named_steps['regressor']
print(f"Лучшее значение alpha: {best_model.alpha_}")
print(f"Лучшее значение l1_ratio: {best_model.l1_ratio_}")
# Out:
# Лучшее значение alpha: 0.42647321101252533
# Лучшее значение l1_ratio: 0.99

# %%
y_pred_log = model_pipeline.predict(X_test)
y_pred_real = y_pred_log
y_test_real = y_test
y_train_pred = model_pipeline.predict(X_train)

# %%
MAE = mean_absolute_error(y_test_real, y_pred_real)
MSE = mean_squared_error(y_test_real, y_pred_real)
RMSE = np.sqrt(MSE)
r2_test = r2_score(y_test_real, y_pred_real)
r2_train = r2_score(y_train, y_train_pred)

# %%
MAE
# Out:
# 155.90716031557454

# %%
MSE
# Out:
# 52261.021413945404

# %%
RMSE
# Out:
# np.float64(228.60669590794012)

# %%
r2_test
# Out:
# 0.7133929746551522

# %%
r2_train
# Out:
# 0.8216400136591555

# %%
df['Price'].mean()
# Out:
# np.float64(741.7807212317665)

# %%
df.head()
# Out:
#   Company   TypeName  Screen_Size Resolution Touchscreen  IPS            CPU  \
# 0   Apple  Ultrabook         13.3  2560x1600          No  Yes  Intel Core i5
# 1   Apple  Ultrabook         13.3   1440x900          No   No  Intel Core i5
# 2      HP   Notebook         15.6  1920x1080          No   No  Intel Core i5
# 3   Apple  Ultrabook         15.4  2880x1800          No  Yes  Intel Core i7
# 4   Apple  Ultrabook         13.3  2560x1600          No  Yes  Intel Core i5
#
#    Clock_Speed  RAM                       GPU  HDD  SSD  Flash_Storage  OpSys  \
# 0          2.3    8  Intel Iris Plus Graphics    0  128              0  MacOS
# 1          1.8    8         Intel HD Graphics    0    0            128  MacOS
# 2          2.5    8         Intel HD Graphics    0  256              0  No OS
# 3          2.7   16           AMD Radeon Pro     0  512              0  MacOS
# 4          3.1    8  Intel Iris Plus Graphics    0  256              0  MacOS
#
#    Weight    Price
# ...

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Mediacom',
#        'Samsung', 'Google', 'Fujitsu', 'Razer', 'LG'], dtype=object)

# %%
df['Resolution'].unique()
# Out:
# array(['2560x1600', '1440x900', '1920x1080', '2880x1800', '1366x768',
#        '2304x1440', '3200x1800', '2256x1504', '3840x2160', '2160x1440',
#        '1600x900', '2560x1440', '2736x1824', '2400x1600', '1920x1200'],
#       dtype=object)

# %%
df['GPU'].unique()
# Out:
# array(['Intel Iris Plus Graphics', 'Intel HD Graphics', 'AMD Radeon Pro ',
#        'AMD Radeon R5', 'Intel Iris Pro Graphics', 'Nvidia GeForce',
#        'Intel UHD Graphics', 'Nvidia GeForce GTX', 'AMD Radeon R2',
#        'AMD Radeon ', 'Intel Iris Graphics', 'AMD Radeon RX ',
#        'AMD Radeon R4', 'AMD R4', 'AMD Radeon R7', 'Nvidia GTX',
#        'Nvidia Quadro', 'AMD FirePro ', 'Intel Graphics', 'AMD Radeon R3',
#        'AMD Radeon R9'], dtype=object)

# %%
df['OpSys'].unique()
# Out:
# array(['MacOS', 'No OS', 'Windows', 'Linux', 'ChromeOS', 'Android'],
#       dtype=object)

# %%
model_pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Company', 'TypeName',
#                                                    'Resolution', 'Touchscreen',
#                                                    'IPS', 'CPU', 'GPU',
#                                                    'OpSys']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures(include_bias=False,
# ...

# %%
y_full_pred = model_pipeline.predict(X)

# %%
best_final_model = model_pipeline.named_steps['regressor']
print(f"Лучшее значение alpha: {best_final_model.alpha_}")
print(f"Лучшее значение l1_ratio: {best_final_model.l1_ratio_}")
# Out:
# Лучшее значение alpha: 0.797110889504034
# Лучшее значение l1_ratio: 0.99

# %%
r2_full = r2_score(y, y_full_pred)

# %%
r2_full
# Out:
# 0.805481807798749

# %%
test = {
    'Company': ['Lenovo'],
    'TypeName': ['Notebook'],
    'Screen_Size': [14.5],
    'Resolution': ['1920x1200'],
    'Touchscreen': ['No'],
    'IPS': ['No'],
    'CPU': ['Intel Core i7'],
    'Clock_Speed': [1.2],
    'RAM': [32],
    'GPU': ['Nvidia GeForce'],
    'HDD': [0],
    "SSD": [2000],
    'Flash_Storage': [64],
    'OpSys': ['Windows'],
    'Weight': [2.3]
    
}

# %%
test_df = pd.DataFrame(test)

# %%
model_pipeline.predict(test_df)
# Out:
# array([1390.4002265])

# %%
import json
import os

advanced_report = {
    "project": "Laptop Price Prediction",
    "model": "ElasticNetCV",
    "trained_date": '2026-07',
    "test_parameters": {
        "alpha": best_model.alpha_,
        "l1_ratio": best_model.l1_ratio_,
        "cv": best_model.cv
    },
    "final_parameters": {
        "alpha": best_final_model.alpha_,
        "l1_ratio":  best_final_model.l1_ratio_,
        "cv": best_final_model.cv
    },
    "metrics": {
        "RMSE": RMSE,
        "MAE": MAE,
        "R2_train": r2_train,
        "R2_test": r2_test,
        "R2_full": r2_full,
        "Mean_Laptop_Price": df['Price'].mean()
    }
}


filename = "model_description.json"

with open(filename, "w", encoding="utf-8") as f:
    json.dump(advanced_report, f, indent=4, ensure_ascii=False)

# %%
from joblib import dump, load

# %%
dump(model_pipeline, 'model/laptop_price_prediction_elastic_net_cv_2026_v1.pkl')
# Out:
# ['model/laptop_price_prediction_elastic_net_cv_2026_v1.pkl']

# %%
loaded_pipe = load('model/laptop_price_prediction_elastic_net_cv_2026_v1.pkl')

# %%
loaded_pipe.predict(test_df)
# Out:
# array([1390.4002265])
